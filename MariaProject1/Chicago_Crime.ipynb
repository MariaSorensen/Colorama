# %% [markdown]
# ### Null Hypothesis Test:

# %% [markdown]
# # Is crime related to population?
#
# **$H_{1}$:p>c**  _where (p) is the Probability of (c) Crime increase_
#
# If crime IS related to population density
# > Then the incidence of crime (Mean occurences) between 2012-2015 in the city of Chicago will be higher in areas where the population is higher
#
# **$H_{0}$:p$\leq$c**
#
# If crime IS NOT related to population density
# >Then crimes occurences will be equal to or lower

# %% [markdown]
# This dataset reflects reported incidents of crime that occurred in the City of Chicago from 2012 to 2015

# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the Crimes_-_2001_to_present file path
crime_path = "Resources/Crimes_-_2001_to_present.csv"

# Import the csv file as a DataFrame
crime_df = pd.read_csv(crime_path, encoding="utf-8")
crime_df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
crime_df['Year'].dtype
# Out:
# dtype('int64')

# %%
Prim_types_df = pd.DataFrame()

# %%
year= [2012, 2013, 2014, 2015]

# %%
Prim_types_df = pd.DataFrame()

# %%
#Calucalate total number types of crimes committed 
#and a description of the crime in the area
#between 2012-2017

# Make a request for each of the years
for x in year:    
    Prim_types_df = pd.concat([Prim_types_df, crime_df[crime_df.Year == x]])
       

#Prim_types = crime_df.groupby("year")["SN"].count()

# %%
Prim_types_df.reset_index().drop('index', axis=1)
# Out:
#                ID Case Number                    Date  \
# 0        10433096    HZ170962  01/01/2012 12:00:00 AM
# 1        10433124    HZ170983  01/01/2012 12:00:00 AM
# 2        11227247    JB147078  01/01/2012 09:00:00 AM
# 3        11228588    JB149037  06/04/2012 12:00:00 PM
# 4        11243251    JB166394  08/07/2012 12:01:00 AM
# 5        11244255    JB169720  01/01/2012 12:01:00 AM
# 6        11230974    JB152462  08/06/2012 12:01:00 AM
# 7        11248976    JB170105  01/01/2012 12:01:00 AM
# 8        11250480    JB177844  01/01/2012 12:01:00 AM
# 9        11251585    JB179410  01/10/2012 12:00:00 AM
# 10       10520780    HZ262685  04/13/2012 12:00:00 AM
# 11       10521090    HZ262624  08/12/2012 12:00:00 PM
# 12       10521199    HZ262885  02/13/2012 07:00:00 PM
# 13        8601634    HV275211  05/07/2012 03:00:00 AM
# 14       11261558    JB192980  10/15/2012 03:00:00 PM
# 15       11262583    JB193146  02/14/2012 12:00:00 AM
# ...

# %%
Primary_types_df = Prim_types_df.loc[:, ["ID", "Date", "Primary Type",
                                    "Description", "Community Area", "Year"]]
Primary_types_df
# Out:
#                ID                    Date                Primary Type  \
# 64596    10433096  01/01/2012 12:00:00 AM                 SEX OFFENSE
# 64618    10433124  01/01/2012 12:00:00 AM                 SEX OFFENSE
# 107497   11227247  01/01/2012 09:00:00 AM          DECEPTIVE PRACTICE
# 229769   11228588  06/04/2012 12:00:00 PM          DECEPTIVE PRACTICE
# 638569   11243251  08/07/2012 12:01:00 AM  OFFENSE INVOLVING CHILDREN
# 639370   11244255  01/01/2012 12:01:00 AM                 SEX OFFENSE
# 639961   11230974  08/06/2012 12:01:00 AM         CRIM SEXUAL ASSAULT
# 649189   11248976  01/01/2012 12:01:00 AM  OFFENSE INVOLVING CHILDREN
# 649940   11250480  01/01/2012 12:01:00 AM                 SEX OFFENSE
# 650336   11251585  01/10/2012 12:00:00 AM                 SEX OFFENSE
# 651678   10520780  04/13/2012 12:00:00 AM          DECEPTIVE PRACTICE
# 652395   10521090  08/12/2012 12:00:00 PM                 SEX OFFENSE
# ...

# %% [markdown]
# ### The types of crimes that occurred in each community area

# %%
type_summary_df = (Primary_types_df.groupby(["Community Area", "Primary Type"])
                    ["ID"].agg(['mean', 'count'])
                  )
type_summary_df
# Out:
#                                                          mean  count
# Community Area Primary Type
# 0.0            CRIMINAL DAMAGE                   9.410321e+06      8
#                CRIMINAL TRESPASS                 9.227380e+06      4
#                DECEPTIVE PRACTICE                8.777926e+06      4
#                MOTOR VEHICLE THEFT               9.027156e+06      4
#                NARCOTICS                         8.655272e+06      2
#                THEFT                             9.346092e+06      4
# 1.0            ARSON                             9.324988e+06     30
#                ASSAULT                           9.352959e+06   2288
#                BATTERY                           9.351513e+06   6652
#                BURGLARY                          9.384882e+06   1492
#                CRIM SEXUAL ASSAULT               9.671151e+06    186
#                CRIMINAL DAMAGE                   9.388862e+06   3734
# ...

# %%
#you will need this code to merge the population data.
# Merge our newly combined dataframe with the 2015 dataframe
#combined_wrestlers_df = pd.merge(combined_wrestlers_df, wrestlers_2015_df, how="outer", on="Wrestler")
#combined_wrestlers_df
