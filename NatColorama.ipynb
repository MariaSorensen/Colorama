# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
import pprint as pprint

# %%
file=r'\Users\n8gre\crimes_-_2001_to_present.csv'
df=pd.read_csv(file)

# %%
df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
df2 = df.loc[:, ["Year", "Location Description", "ID"]]
df3=df2.loc[(df2["Year"]>2011)]
df4=df3.loc[(df3["Year"]<2016)]

# %%
#df.pivot(index='ID', columns='Year', values='Location Description')

# %%
loc=df4.groupby(["Location Description", "Year"])["ID"].count()
loc
# Out:
# Location Description                                   Year
# ABANDONED BUILDING                                     2012    1036
#                                                        2013     977
#                                                        2014     680
#                                                        2015     526
# AIRCRAFT                                               2012      46
#                                                        2013      61
#                                                        2014      74
#                                                        2015     107
# AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA        2012     102
#                                                        2013      67
#                                                        2014      73
#                                                        2015      78
# AIRPORT BUILDING NON-TERMINAL - SECURE AREA            2012      54
# ...

# %%
loc.apply.count("Year")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-e2a2b19d1edb> in <module>
# ----> 1 loc.apply.count("Year")
#
# AttributeError: 'function' object has no attribute 'count'
