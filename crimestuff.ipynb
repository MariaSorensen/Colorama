# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
file='crime_data.csv'
df=pd.read_csv(file)

# %%
df.head()
# Out:
#      year   population  violent crime  violent crime rate  \
# 0  1994.0  260327021.0      1857670.0               713.6
# 1  1995.0  262803276.0      1798792.0               684.5
# 2  1996.0  265228572.0      1688540.0               636.6
# 3  1997.0  267783607.0      1636096.0               611.0
# 4  1998.0  270248003.0      1533887.0               567.6
#
#    murder and non-negligent manslaughter  \
# 0                                23326.0
# 1                                21606.0
# 2                                19645.0
# 3                                18208.0
# 4                                16974.0
#
#     murder and non-negligent manslaughter rate      rape  rape rate   robbery  \
# 0                                          9.0  102216.0       39.3  618949.0
# 1                                          8.2   97470.0       37.1  580509.0
# 2                                          7.4   96252.0       36.3  535594.0
# ...

# %%
df_y=df.iloc[:,0]
df_vr=df.iloc[:,3]
cr_slope, cr_int, = stats.linregress(df_y,df_cr)
cr_fit = cr_slope * y + cr_int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-71dae987240e> in <module>
#       1 df_y=df.iloc[:,0]
#       2 df_vr=df.iloc[:,3]
# ----> 3 cr_slope, cr_int, = stats.linregress(df_y,df_cr)
#       4 cr_fit = cr_slope * y + cr_int
#       5
#
# ValueError: too many values to unpack (expected 2)

# %%
df_mr=df.iloc[:,5]
mr_slope, mr_int, = stats.linregress(df_y,df_mr)
mr_fit = mr_slope * y + mr_int

# %%
df_ar=df.iloc[:,11]
ar_slope, ar_int, = stats.linregress(af_y,df_ar)
ar_fit = ar_slope * y + ar_int

# %%
stats.linegress(df_y,df_vr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-877169e3578e> in <module>
# ----> 1 stats.linegress(df_y,df_vr)
#
# AttributeError: module 'scipy.stats' has no attribute 'linegress'
